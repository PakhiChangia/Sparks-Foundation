# %% [markdown]
# # THE SPARKS FOUNDATION : Data Science & Business Analytics Intern

# %% [markdown]
# ## Task 3: Exploratory Data Analysis : Retail

# %% [markdown]
# As a Business Manager, we have to find out the weak areas where we can work to make more profit.

# %% [markdown]
# # Submitted By: PAKHI CHANGIA

# %%
#Importing all the libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
#Read the data
url=r"C:\Users\kc\Downloads\SampleSuperstore.csv"
df=pd.read_csv(url)
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9988    Second Class   Consumer  United States            Miami     Florida
# 9989  Standard Class   Consumer  United States       Costa Mesa  California
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9988        33180  South        Furniture  Furnishings   25.2480         3
# 9989        92627   West        Furniture  Furnishings   91.9600         2
# 9990        92627   West       Technology       Phones  258.5760         2
# 9991        92627   West  Office Supplies        Paper   29.6000         4
# 9992        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9988      0.20    4.1028
# 9989      0.00   15.6332
# 9990      0.20   19.3932
# 9991      0.00   13.3200
# 9992      0.00   72.9480
#
# [9993 rows x 13 columns]

# %%
# checking if there are any null values in the dataset
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#Checking the duplicate values
df.duplicated().sum()
# Out:
# 17

# %%
#Dropping the duplicate values
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (9976, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9976 entries, 0 to 9992
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9976 non-null   object
#  1   Segment       9976 non-null   object
#  2   Country       9976 non-null   object
#  3   City          9976 non-null   object
#  4   State         9976 non-null   object
#  5   Postal Code   9976 non-null   int64
#  6   Region        9976 non-null   object
#  7   Category      9976 non-null   object
#  8   Sub-Category  9976 non-null   object
#  9   Sales         9976 non-null   float64
#  10  Quantity      9976 non-null   int64
#  11  Discount      9976 non-null   float64
#  12  Profit        9976 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 779.4+ KB

# %%
#Statitical information of the dataset
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9976.000000   9976.000000  9976.000000  9976.000000  9976.000000
# mean   55151.468023    230.000943     3.790196     0.156274    28.684454
# std    32057.971618    623.577550     2.226158     0.206465   234.468907
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.295000     2.000000     0.000000     1.725850
# 50%    55901.000000     54.804000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.970000     5.000000     0.200000    29.366000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.drop(['Postal Code'],axis=1,inplace=True)

# %% [markdown]
# ## Visualization

# %%
sns.set_style("whitegrid")
sns.pairplot(df)

# %%
print(df.corr())
sns.heatmap(df.corr(),annot=True,cmap="inferno")
plt.title("Correlation between Variables",size=20)
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200278 -0.028369  0.479146
# Quantity  0.200278  1.000000  0.008631  0.066172
# Discount -0.028369  0.008631  1.000000 -0.219668
# Profit    0.479146  0.066172 -0.219668  1.000000
# Text(0.5, 1.0, 'Correlation between Variables')

# %%
plt.figure(figsize=(5,5))
plt.pie(df['Ship Mode'].value_counts(),labels=df['Ship Mode'].value_counts().index,autopct="%1.1f%%")
plt.title("Ship Mode",fontsize=25)
plt.show()

# %%
plt.pie(df['Segment'].value_counts(),labels=df['Segment'].value_counts().index,autopct="%1.1f%%")
plt.title("Segment",size=20)
plt.show()

# %%
plt.pie(df['Region'].value_counts(),labels=df['Region'].value_counts().index,autopct="%1.1f%%")
plt.title("Region",size=20)
plt.show()

# %%
plt.pie(df['Category'].value_counts(),labels=df['Category'].value_counts().index,autopct="%1.1f%%")
plt.title("Category",size=20)
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.pie(df['Sub-Category'].value_counts(),labels=df['Sub-Category'].value_counts().index,autopct="%0.1f%%")
plt.title("Sub-Category",size=20)
plt.show()

# %%
fig,axes=plt.subplots(1,2,figsize=(14,5))
fig.suptitle("Sales with different Shipping Modes and Segments",size=15)
sns.lineplot(x="Ship Mode",y="Sales",data=df,ax=axes[0])
sns.lineplot(x="Segment",y="Sales",data=df,ax=axes[1])
plt.show()

# %%
df.groupby("Category")["Profit","Sales"].agg(["sum"]).plot.bar()
plt.title("Total Profits and Sales based on different Category")
plt.show()

# %%
df.groupby("Sub-Category")["Profit","Sales"].agg(["sum"]).plot.bar()
plt.title("Total Profits and Sales based on different Sub-Category")
plt.show()

# %%
df.groupby("Region")["Profit","Sales"].agg(["sum"]).plot.bar()
plt.title("Total Profits and Sales based on Regions")
plt.show()

# %%
fig,axes=plt.subplots(1,2,figsize=(14,5))
fig.suptitle("Total Sales Vs Profit",size=18)
sns.barplot("Category","Sales",hue="Region",data=df,ax=axes[0]).set_title("Category Vs Sales based on different Regions")
sns.barplot("Category","Profit",hue="Region",data=df,ax=axes[1]).set_title("Category Vs Profit based on different Regions")
# Out:
# Text(0.5, 1.0, 'Category Vs Profit based on different Regions')

# %%
fig,axes=plt.subplots(2,1,figsize=(14,7))
fig.suptitle("Total Sales Vs Profits",size=18)
sns.barplot("Sub-Category","Sales",hue="Region",data=df,ax=axes[0])
sns.barplot("Sub-Category","Profit",hue="Region",data=df,ax=axes[1])
plt.show()

# %%
plt.title("Discounts Vs Profits")
sns.lineplot(x="Discount",y="Profit",data=df)
# Out:
# <AxesSubplot:title={'center':'Discounts Vs Profits'}, xlabel='Discount', ylabel='Profit'>

# %% [markdown]
# #### Thank You
